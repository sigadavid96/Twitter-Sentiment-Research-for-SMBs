# %%
import pandas as pd

# %%
# Importing the data
df_tweets=pd.read_csv("/content/forSentiment.csv")

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
df_tweets
# Out:
#      Unnamed: 0  Unnamed: 0.1                      created_at  \
# 0             0             0  Sat Jan 01 23:55:31 +0000 2022
# 1             1             1  Sat Jan 01 23:52:53 +0000 2022
# 2             2             2  Sat Jan 01 23:48:23 +0000 2022
# 3             3             3  Sat Jan 01 23:25:45 +0000 2022
# 4             4             4  Sat Jan 01 23:22:14 +0000 2022
# ..          ...           ...                             ...
# 995         995           995  Wed Dec 29 12:04:30 +0000 2021
# 996         996           996  Wed Dec 29 12:02:05 +0000 2021
# 997         997           997  Wed Dec 29 12:01:12 +0000 2021
# 998         998           998  Wed Dec 29 12:01:01 +0000 2021
# 999         999           999  Wed Dec 29 11:52:22 +0000 2021
#
#                       id               id_str  \
# 0    1477428304277917696  1477428304277917696
# 1    1477427641615413251  1477427641615413251
# 2    1477426506511306756  1477426506511306756
# 3    1477420814156840960  1477420814156840960
# 4    1477419926231162882  1477419926231162882
# ..                   ...                  ...
# 995  1476162205976604677  1476162205976604677
# 996  1476161600012709888  1476161600012709888
# 997  1476161378247495683  1476161378247495683
# 998  1476161328440127493  1476161328440127493
# 999  1476159153340964866  1476159153340964866
#
#                                                   text  \
# 0    I have so many bumper sticker ideas would yall...
# 1    People will say “support small businesses” the...
# 2    As individuals, we do what we know to be right...
# 3    @synbiocs No one’s ever made a successful ML m...
# 4    random Instagram user: ugh how DARE you purcha...
# ..                                                 ...
# 995  @_Neeshuur Not gonna lie, I would agree 100% b...
# 996  Government support for Australian artists &amp...
# 997  bring on the winter season! \n❄️❄️❄️❄️❄️❄️❄️❄️...
# 998  Digital resources that support small businesse...
# 999  Support our small business of buisness blaster...
#
#                                                 source  truncated  \
# 0    <a href="http://twitter.com/download/iphone" r...      False
# 1    <a href="http://twitter.com/download/iphone" r...       True
# 2    <a href="http://twitter.com/download/iphone" r...       True
# 3    <a href="http://twitter.com/download/iphone" r...       True
# 4    <a href="https://mobile.twitter.com" rel="nofo...       True
# ..                                                 ...        ...
# 995  <a href="http://twitter.com/download/android" ...      False
# 996  <a href="http://twitter.com/download/iphone" r...       True
# 997  <a href="http://instagram.com" rel="nofollow">...       True
# 998  <a href="https://www.hootsuite.com" rel="nofol...       True
# 999  <a href="https://mobile.twitter.com" rel="nofo...       True
#
#      in_reply_to_status_id  in_reply_to_status_id_str  ...  extended_entities  \
# 0                      NaN                        NaN  ...                NaN
# 1             1.477427e+18               1.477427e+18  ...                NaN
# 2             1.477427e+18               1.477427e+18  ...                NaN
# 3             1.476651e+18               1.476651e+18  ...                NaN
# 4                      NaN                        NaN  ...                NaN
# ..                     ...                        ...  ...                ...
# 995           1.475953e+18               1.475953e+18  ...                NaN
# 996                    NaN                        NaN  ...                NaN
# 997                    NaN                        NaN  ...                NaN
# 998                    NaN                        NaN  ...                NaN
# 999                    NaN                        NaN  ...                NaN
#
#      quoted_status_id quoted_status_id_str  \
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
# ..                ...                  ...
# 995               NaN                  NaN
# 996      1.476059e+18         1.476059e+18
# 997               NaN                  NaN
# 998               NaN                  NaN
# 999               NaN                  NaN
#
#                                          quoted_status  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                                NaN
# 996  {'created_at': 'Wed Dec 29 05:13:29 +0000 2021...
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                quoted_status_permalink  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                                NaN
# 996  {'url': 'https://t.co/XCsVawiuaN', 'expanded':...
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                        processed_texts  \
# 0                  many bumper sticker idea would yall
# 1    people say angry ship 24 hour angry offer exch...
# 2    individual know right take precaution help com...
# 3    synbiocs one ever made successful ml model ven...
# 4    random instagram user ugh dare purchase fast f...
# ..                                                 ...
# 995  neeshuur gon na lie would agree 100 got friend...
# 996  government australian artist musician music wo...
# 997  bring winter season knit ready iknitchicago wi...
# 998  digital resource become resilient becoming pre...
# 999           buisness blaster dm information msisodia
#
#                                                    POS       location  \
# 0    [('many', 'JJ'), ('bumper', 'JJR'), ('sticker'...            NaN
# 1    [('people', 'NNS'), ('say', 'VBP'), ('angry', ...            NaN
# 2    [('individual', 'JJ'), ('know', 'VB'), ('right...            NaN
# 3    [('synbiocs', 'NN'), ('one', 'CD'), ('ever', '...            NaN
# 4    [('random', 'NN'), ('instagram', 'NNS'), ('use...            NaN
# ..                                                 ...            ...
# 995  [('neeshuur', 'JJ'), ('gon', 'NN'), ('na', 'TO...            NaN
# 996  [('government', 'NN'), ('australian', 'JJ'), (...            NaN
# 997  [('bring', 'NN'), ('winter', 'NN'), ('season',...  United States
# 998  [('digital', 'JJ'), ('resource', 'NN'), ('beco...            NaN
# 999  [('buisness', 'NN'), ('blaster', 'NN'), ('dm',...            NaN
#
#      location_code                                       text_cleaned
# 0              NaN          many bumper sticker idea would -PRON- all
# 1              NaN    people say angry ship hour angry offer exchange
# 2              NaN  individual know right take precaution help com...
# 3              NaN  synbiocs one ever make successful ml model ven...
# 4              NaN  random instagram user ugh dare purchase fast f...
# ..             ...                                                ...
# 995            NaN  neeshuur gon na lie would agree get friend clo...
# 996            NaN  government australian artist musician music wo...
# 997             US   bring winter season knit ready iknitchicago snow
# 998            NaN  digital resource become resilient become preva...
# 999            NaN           buisness blaster dm information msisodia
#
# [1000 rows x 45 columns]

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

df_sentiment = df_tweets.copy()

# instantiate new SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

sentiment_scores = df_sentiment['text_cleaned'].progress_apply(sid.polarity_scores)
sentiment = sentiment_scores.apply(lambda x: x['compound'])
df_sentiment['sentiment'] = sentiment
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-3c3147aa6082> in <module>()
#       6 sid = SentimentIntensityAnalyzer()
#       7
# ----> 8 sentiment_scores = df_sentiment['text_cleaned'].progress_apply(sid.polarity_scores)
#       9 sentiment = sentiment_scores.apply(lambda x: x['compound'])
#      10 df_sentiment['sentiment'] = sentiment
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'progress_apply'
